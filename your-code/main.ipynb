# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

from scipy.stats import uniform

import scipy.stats as stats

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
x = uniform.rvs(size=20)
a = 4
b = 5
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [4.78565112 4.04061802 4.94088245 4.69503284 4.39756837 4.54513957
#  4.86118531 4.91774967 4.8935107  4.2431776  4.91964542 4.62828916
#  4.62027196 4.66136386 4.34616804 4.67593356 4.47491727 4.93462315
#  4.2719864  4.05395181]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
# 1- function that generates normal distributed random numbers
def random(bottom,ceiling,count):
    x = uniform.rvs(size=count)
    randoms  = a + (b-a)*x
    return randoms

# %%
# your code here
# 2- Call your function1
random1= random(10,19,100)

# %% [markdown]
# How are the two distributions different?

# %%
# your code here
# 3- Call your function2
random2= random(10,80,300)

# %%
# 4- Plot the uniform distributions generated above 
plt.figure(figsize=(20, 12))

sns.histplot(random1, bins=20, kde=True, color='skyblue', edgecolor='black')
sns.histplot(random2, bins=20, kde=True, color='red', edgecolor='black')

plt.legend(['random1', 'random2'])
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Numbers')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
#1-function that generates normal distributed random numbers
def normal_function(mean,standard_deviation,count):
    return stats.norm(mean, standard_deviation).rvs(size = count)

# %%
# your code here
#2-Call your function1
random1=normal_function(10,1,1000)

# %%
# your code here
#3-Call your function2
random2=normal_function(10,50,1000)

# %%
# your code here
#Plot the uniform distributions generated above 
sns.set()
sns.histplot(random1, kde=True, bins=30, alpha=0.5, label='random1')
sns.histplot(random2, kde=True, bins=30, alpha=0.5, label='random2')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Normal Distributions')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here
# The two distributions have the same mean (10), but differ in their spread. The first distribution has a smaller standard deviation of 1, resulting in a narrower peak. The second distribution has a larger standard deviation of 50, causing a wider peak. This difference in standard deviation is the main difference between the two distributions.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
data = pd.read_csv('//Users/ituaeriaye/Downloads/vehicles.csv')
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
data.hist("Fuel Barrels/Year");

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
data.hist("CO2 Emission Grams/Mile");

# %%
# your code here

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
data.hist("Combined MPG");

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Barrels and emission normal, MPG left skew

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
#create a function that returns a list of numbers exponentially distributed with the mean of 10
def exponential_function(mean,size):
     return np.random.exponential(mean,size)

#Use the function to generate two number sequences with the size of 1 and 100.
result1= exponential_function(10,1)
result2= exponential_function(10,100)

#Plot the distributions as histograms with the nubmer of bins as 100
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.hist(result1, bins=100);
ax2.hist(result2, bins=100);

# %% [markdown]
# How are the two distributions different?
# No variation can be seen when size is 1

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here

# %%
# your answer here
# Hint: This is same as saying P(x<15)
stats.expon(1/10).cdf(15)
less15=stats.expon(scale = 10).cdf(15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here
stats.expon(1/10).sf(15)
# Out:
# 3.3807434839047367e-07
